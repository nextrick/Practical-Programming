# %% [markdown]
# # Lesson1-Part5

# %% [markdown]
# ### Video
#
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/lckCZxCj5is" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
# ### Objectives
#
# 1. Tabular and Collaborative Filtering
# 2. Jupyter Notebook in Fast.ai
# 3. Applications of Deep Learning
# 4. History and Basics of Machine Learning
# 5. General Guidelines
#
# ###  Highlights
#
# Following were the highlight's:
#
# 1. Remaking Fastai Course Practical Deep Learning 2022
# [Original Course](https://course.fast.ai/)
# 2. Lesson 1 Smaller Version – This one is Part 5 of lesson
# 3. Useful Links (link no. 15 to 20) and notes are provided in google drive (link no. 1 in Resource Section also in description)
#
# ## Readings
#
# > So If you finished watching video there are notes and slides available for you. Feel free to download that and you can do a quick review of the lesson
#
#
# ### Slides
#
# > Click to Slide Show to View Full
#
# <iframe src="https://docs.google.com/presentation/d/1HJnCFlvw3bOCUVR9XqLsohrbscDmd7-UKJPHYrGzVBc/edit?usp=share_link" width="540" height="530" allow="autoplay"></iframe>
#
#
# ### Notes (Part 5)
#
# > Click to Top right icon to download notes.
#
# <iframe src="https://drive.google.com/file/d/1XXmtQSQ3uH6X-bs3tZY-hyLXsP95fdsM/preview" width="540" height="530" allow="autoplay"></iframe>
#
#
# ### Chapter 1 Book
# > This is updated version of Chapter 1 of Book [Deep Learning for Coders With Fastai and Pytorch: AI Applications Without a Phd](https://www.amazon.it/Deep-Learning-Coders-Fastai-Pytorch/dp/1492045527/ref=asc_df_1492045527/?tag=googshopit-21&linkCode=df0&hvadid=459292103653&hvpos=&hvnetw=g&hvrand=17885666003159351137&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=20613&hvtargid=pla-917301026067&psc=1)
#
# > I modified code according to new version of fastai library
#
# <script src="https://gist.github.com/HafizAhmadHassan/bf82bf76b4c87bde35628eabfe75d34b.js"></script>
#
#
# ### Resources :
#
#
# 1. [Slides and Lecture Notes](https://drive.google.com/drive/folders/15ODbJIV4dGzHLTusXKjoy5mjNJq8FtQo?usp=share_link)
# 2. [Original Lesson Video](https://course.fast.ai/Lessons/lesson1.html)
# 3. [Free Book Version](https://github.com/fastai/fastbook)
# 4. [Amazon Book](https://www.amazon.com/Deep-Learning-Coders-fastai-PyTorch/dp/1492045527)
# 5. [Image Analysis Tool PixSpy](https://pixspy.com/)
# 6. [Dalle Text to Image Generator](https://openai.com/dall-e-2/)
# 7. [The Pytorch Image Model](https://timm.fast.ai/)
# 8. [fast.ai Library Documentation](https://docs.fast.ai/)
# 9. [Fast.ai Course 2017](https://course17.fast.ai/)
# 10. [ULMfit Paper With Code](https://paperswithcode.com/method/ulmfit)
# 11. [Kaggle Notebook](https://www.kaggle.com/ahmadhassan061/lesson1)
# 12. [Medium.com Article Blog](https://medium.com/@l154359/introduction-to-fastai-2022-lesson-1-part-5-175ebb20f7e3)
# 13. [Kaggle Notebook Jhoward](https://www.kaggle.com/jhoward/notebooks)
# 14. [Kaggle Notebook Is it a Bird Classifier](https://www.kaggle.com/code/jhoward/is-it-a-bird-creating-a-model-from-your-own-data)
# 15. [Tabular Model](https://docs.fast.ai/tutorial.tabular.html)
# 16. [Collaborative Filtering](https://docs.fast.ai/tutorial.collab.html)
# 17. [Rise Extension Jupyter Notebook](https://rise.readthedocs.io/en/stable/)
# 18. [Fastpages Fast.ai](https://fastpages.fast.ai/jupyter/2020/02/20/test.html)
# 19. [Testing Fast.ai](https://github.com/fastai/fastai/actions)
# 20. [Share Your Work Fast.ai](https://forums.fast.ai/t/share-your-work-here/96015)
# 21. [Graphviz Extension](https://graphviz.readthedocs.io/en/stable/manual.html)
#
# <br>
# <a href="https://hafizahmadhassan.github.io/mynbdev_cards/lesson1-part4.html" style="text-align:left;color: blue;
# ">
# <== Lesson1-Part4</a>
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# <a href="https://hafizahmadhassan.github.io/mynbdev_cards/lesson2-part1.html" style="text-align:right;color: blue;
# ">Lesson2-Part1 ==></a>
#
#
# ## Acknowledgements
#
# Special Thanks to @Jeremy Howard
