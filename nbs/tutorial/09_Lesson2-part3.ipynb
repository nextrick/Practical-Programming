# %% [markdown]
# # Lesson2-Part3

# %% [markdown]
# This is about Deployment.
#
# ### Video
#
# Uploading Soon!
#
#
# ### Outline
#
# 1. HuggingFace Api
# 2. Example How HuggingFace Api Works
# 3. Example of HuggingFace Api With Javascript
# 4. Analysis of Javascript Api ( file 1single.html )
# 5. Analysis of Javascript Api ( file 1multi.html )
# 6. Another Example of Javascript Application
# 7. How to Make Own Website ? Model Deployment
# 8. Local Website to Public With Github Pages
# 9. Introduction to Fastpages
# 10. Adding Theme to Website Alembic
#
#
#
# ###  Highlights
#
# Following were the highlight's:
#
# 1. Remaking Fastai Course Practical Deep Learning 2022 [Original Course](https://course.fast.ai/)
# 2. Lesson 2 Smaller Version – This one is Part 3 of lesson
# 3. Notes are provided in google drive (link no. 1 in Resource Section also in description of Video)
#
# ## Readings
#
# > So If you finished watching video there are notes and slides available for you. Feel free to download that and you can do a quick review of the lesson
#
# ### Slides
#
# > Click to Slide Show to View Full
#
# > To Download [Click Here](https://docs.google.com/presentation/d/1XCSc8RRwxoXDX3FnFutplrIxYfQFDwrQQlhQwbAZyO8/edit?usp=share_link)
#
#
# <iframe src="https://docs.google.com/presentation/d/1XCSc8RRwxoXDX3FnFutplrIxYfQFDwrQQlhQwbAZyO8/edit?usp=share_link" width="540" height="530" allow="autoplay"></iframe>
#
#
# ### Notes (Part 3)
#
# <iframe src="https://drive.google.com/file/d/1jYnOqys9xZ34HiLK__ll5kWQRXSGv1gu/preview" width="540" height="530" allow="autoplay"></iframe>
#
#
#
#
#
# ### Book: Chapter-2 Production (ipynb)
#
# > This is updated version of Chapter 2 of Book [Deep Learning for Coders With Fastai and Pytorch: AI Applications Without a Phd](https://www.amazon.it/Deep-Learning-Coders-Fastai-Pytorch/dp/1492045527/ref=asc_df_1492045527/?tag=googshopit-21&linkCode=df0&hvadid=459292103653&hvpos=&hvnetw=g&hvrand=17885666003159351137&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=20613&hvtargid=pla-917301026067&psc=1)
#
# > I modified code according to new version of fastai library
#
# <script src="https://gist.github.com/HafizAhmadHassan/c3ff0c09086bf1729d34b04523b7d9f4.js"></script>
#
#
# ### Resources :
#
#
# 1. [Slides and Lecture Notes](https://drive.google.com/drive/folders/1u_CI-SznnCLlhNjCIiyE3qdQJvpKs14s?usp=share_link)
# 2. [Original Lesson](https://course.fast.ai/Lessons/lesson2.html)
# 3. [Amazon Book](https://www.amazon.com/Deep-Learning-Coders-fastai-PyTorch/dp/1492045527)
# 4. [Free Book Version](https://github.com/fastai/fastbook)
# 5. [Collab Setup](https://course20.fast.ai/start_colab)
# 6. [Share Your Work](https://forums.fast.ai/t/share-your-work-here/96015)
# 7. [Chapter 2: Production](https://github.com/fastai/fastbook/blob/master/02_production.ipynb)
# 8. [Github Pages](https://pages.github.com/)
# 9. [Tanishq Blog: HuggingFace and Gradio](https://tmabraham.github.io/blog/gradio_hf_spaces_tutorial)
# 10. [HuggingFace Spaces](https://huggingface.co/spaces)
# 11. [Fastpages](https://fastpages.fast.ai/fastpages/jupyter/2020/02/21/introducing-fastpages.html)
# 12. [Forums Lesson2 Official Topic](https://forums.fast.ai/t/lesson-2-official-topic/96033)
# 13. [Kaggle Lesson2 Link](https://www.kaggle.com/code/jhoward/saving-a-basic-fastai-model/notebook)
# 14. [Colab Lesson2 Link](https://colab.research.google.com/drive/1M-mzhZdFQ2XWBSbLCuKzrmLsm0aLEYxQ?usp=sharing)
# 15. [Documentation Fastai](https://docs.fast.ai/)
#
# <br>
# <a href="https://hafizahmadhassan.github.io/mynbdev_cards/lesson2-part2.html" style="text-align:left;color: blue;
# ">
# <== Lesson2-Part2</a>
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# <a href="https://hafizahmadhassan.github.io/mynbdev_cards/lesson3-part1.html" style="text-align:right;color: blue;
# ">Lesson3-Part1 ==></a>
#
# ## Acknowledgements
#
# Special Thanks to @Jeremy Howard
