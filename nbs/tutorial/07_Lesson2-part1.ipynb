# %% [markdown]
# # Lesson2-Part1

# %% [markdown]
# This is about Deployment.
#
# ### Video
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rfICJJyBYiU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
#
# ### Objectives
#
# 1. Guidelines to Book Usage
# 2. Usage of Forums
# 3. Share of Work : Applications by Students
# 4. Put the Model in Production: Gathering and Cleaning Data
# 5. Jupyter Notebook Extensions : Navigation Menu
# 6. Chapter 2 : Preprocessing ,  Data Augmentation , Training and Evaluation
#
# ###  Highlights
#
# Following were the highlight's:
#
# 1. Remaking Fastai Course Practical Deep Learning 2022 [Original Course](https://course.fast.ai/)
# 2. Lesson 2 Smaller Version – This one is Part 1 of lesson
# 3. Useful Links (link no. 2 to 13) and notes are provided in google drive (link no. 1 in Resource Section also in description)
#
# ## Readings
#
# > So If you finished watching video there are notes and slides available for you. Feel free to download that and you can do a quick review of the lesson
#
#
# ### Slides
#
# > Click to Slide Show to View Full
#
# > To Download [Click Here](https://docs.google.com/presentation/d/1-q5-K9kB0Wx3W0ewe6hhSTFF-7OmjLczSEv-EZBDIWE/edit?usp=share_link)
#
# <iframe src="https://docs.google.com/presentation/d/1-q5-K9kB0Wx3W0ewe6hhSTFF-7OmjLczSEv-EZBDIWE/edit?usp=share_link" width="540" height="530" allow="autoplay"></iframe>
#
#
# ### Notes (Part 1)
#
# <iframe src="https://drive.google.com/file/d/14nyJtDlJHgEgFlnJTuZXfNijJIhuLPLH/preview" width="540" height="530" allow="autoplay"></iframe>
#
#
# ### Book: Chapter-2 Production (ipynb)
#
# > This is updated version of Chapter 2 of Book [Deep Learning for Coders With Fastai and Pytorch: AI Applications Without a Phd](https://www.amazon.it/Deep-Learning-Coders-Fastai-Pytorch/dp/1492045527/ref=asc_df_1492045527/?tag=googshopit-21&linkCode=df0&hvadid=459292103653&hvpos=&hvnetw=g&hvrand=17885666003159351137&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=20613&hvtargid=pla-917301026067&psc=1)
#
# > I modified code according to new version of fastai library
#
# <script src="https://gist.github.com/HafizAhmadHassan/c3ff0c09086bf1729d34b04523b7d9f4.js"></script>
#
#
# ### Resources :
#
#
# 1. [Slides and Lecture Notes](https://drive.google.com/drive/folders/1u_CI-SznnCLlhNjCIiyE3qdQJvpKs14s?usp=share_link)
# 2. [Original Lesson Video](https://course.fast.ai/Lessons/lesson2.html)
# 3. [Medium.com Blog](https://medium.com/@l154359/introduction-to-fastai-2022-lesson-2-part-1-8965e2eba421)
# 4. [Amazon Book](https://www.amazon.com/Deep-Learning-Coders-fastai-PyTorch/dp/1492045527)
# 5. [Book With Colab](https://course20.fast.ai/start_colab)
# 6. [AiQuizzes](https://aiquizzes.com/)
# 7. [Forums Lesson 1 Official Topic](https://forums.fast.ai/t/lesson-1-official-topic/95287)
# 8. [Forums Share Your Work](https://forums.fast.ai/t/share-your-work-here/96015)
# 9. [Deployed Application With Hugging Face](https://huggingface.co/spaces/suvash/food-101-resnet50)
# 10. [Jupyter Notebook Extensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
# 11. [Fastbook Free](https://github.com/fastai/fastbook)
# 12. [Chapter 2 - Fastbook](https://github.com/fastai/fastbook/blob/master/02_production.ipynb)
# 13. [Computer Vision Model](https://timm.fast.ai/)
# 14. [Documentation of fastai](hhttps://docs.fast.ai/)
#
#
#
# <br>
# <a href="https://hafizahmadhassan.github.io/mynbdev_cards/lesson1-part5.html" style="text-align:left;color: blue;
# ">
# <== Lesson1-Part5</a>
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# <a href="https://hafizahmadhassan.github.io/mynbdev_cards/lesson2-part2.html" style="text-align:right;color: blue;
# ">Lesson2-Part2 ==></a>
#
#
# ## Acknowledgements
#
# Special Thanks to @Jeremy Howard
